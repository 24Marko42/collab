# %% [markdown]
# <a href="https://colab.research.google.com/github/24Marko42/collab/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Создайте объект Series, значениями которого являются целые числа от 1 до 5, а индексами символы 'a', 'b', 'c', 'd', 'e'.

# %%
import pandas as pd

data = [1, 2, 3, 4, 5]
index = ['a', 'b', 'c', 'd', 'e']

series = pd.Series(data, index=index)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# 2. С помощью обращения по явному индексу получите значение 4.

# %%
print(series['d'])
# Out:
# 4

# %% [markdown]
# 3. С помощью обращения по неявному индексу получите значение 2.

# %%
print(series.iloc[1])
# Out:
# 2

# %% [markdown]
# 4. Добавьте в серию новый элемент.

# %%
series['f'] = 6
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %% [markdown]
# 5. Используя операцию среза, получите значения 3, 4, 5.

# %%
print(series['c':'e'])
# Out:
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# 6. Создайте объект DataFrame из списка [1, 2], [5, 3], [3.7, 4.8] с именами столбцов col1 и col2.

# %%
data_df = [[1, 2], [5, 3], [3.7, 4.8]]
df = pd.DataFrame(data_df, columns=['col1', 'col2'])
print(df)
# Out:
#    col1  col2
# 0   1.0   2.0
# 1   5.0   3.0
# 2   3.7   4.8

# %% [markdown]
# 7. Используя операцию индексации, получите элемент 3.7.

# %%
print(df.loc[2, 'col1'])
# Out:
# 3.7

# %% [markdown]
# 8. Измените элемент 3 на 9.

# %%
df.loc[1, 'col2'] = 9
print(df)
# Out:
#    col1  col2
# 0   1.0   2.0
# 1   5.0   9.0
# 2   3.7   4.8

# %% [markdown]
# 9. Используя операцию среза, получите строки с индексами 1 и 2.

# %%
print(df.loc[1:2])
# Out:
#    col1  col2
# 1   5.0   9.0
# 2   3.7   4.8

# %% [markdown]
# 10. Добавьте столбец col3, значения которого – результат поэлементного
# перемножения col1 и col2.

# %%
df['col3'] = df['col1'] * df['col2']
print(df)
# Out:
#    col1  col2   col3
# 0   1.0   2.0   2.00
# 1   5.0   9.0  45.00
# 2   3.7   4.8  17.76
